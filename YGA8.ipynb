# %%
df = pd.read_csv('Titanic Dataset.zip')
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
dataset = sns.load_dataset('Titanic Dataset.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5437/3469276262.py in <module>
# ----> 1 dataset = sns.load_dataset('Titanic Dataset.csv')
#
# ~/.local/lib/python3.10/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     581         if not os.path.exists(cache_path):
#     582             if name not in get_dataset_names():
# --> 583                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     584             urlretrieve(url, cache_path)
#     585         full_path = cache_path
#
# ValueError: 'Titanic Dataset.csv' is not one of the example datasets.

# %%
dataset = sns.load_dataset('Titanic Dataset')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5437/1434410705.py in <module>
# ----> 1 dataset = sns.load_dataset('Titanic Dataset')
#
# ~/.local/lib/python3.10/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     581         if not os.path.exists(cache_path):
#     582             if name not in get_dataset_names():
# --> 583                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     584             urlretrieve(url, cache_path)
#     585         full_path = cache_path
#
# ValueError: 'Titanic Dataset' is not one of the example datasets.

# %%
dataset = sns.load_dataset('Titanic Dataset.zip')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5437/4196624015.py in <module>
# ----> 1 dataset = sns.load_dataset('Titanic Dataset.zip')
#
# ~/.local/lib/python3.10/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     581         if not os.path.exists(cache_path):
#     582             if name not in get_dataset_names():
# --> 583                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     584             urlretrieve(url, cache_path)
#     585         full_path = cache_path
#
# ValueError: 'Titanic Dataset.zip' is not one of the example datasets.

# %%
sns.distplot(df['fare'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802             try:
# -> 3803                 return self._engine.get_loc(casted_key)
#    3804             except KeyError as err:
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fare'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dataset = sns.load_dataset('titanic')

# %%
sns.distplot(dataset['fare'])
# Out:
# /tmp/ipykernel_5437/1694218074.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['fare'])
# <AxesSubplot:xlabel='fare', ylabel='Density'>
